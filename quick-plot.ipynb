# %%
import matplotlib.pyplot as plt

# %%
plt.rcParams["figure.figsize"] = [18,9]
plt.rcParams["font.size"] = 16

# %%
n = [5,189,2224]
avg_1 = [0.025995696, 0.264018013, 81.14221255]
avg_1err= [0.002963916, 0.013367526, 1.083936324]
avg_2 = [0.02966805, 0.488736937, 136.819104]
avg_2err = [0.002474906, 0.011175994, 2.471472704]
avg_3 = [0.036099565, 0.733438582, 251.0085946]
avg_3err = [0.004112063, 0.086357088, 9.066039635]
avg_4 = [0.039083068, 0.953876822, 406.000502]
avg_4err = [0.001463875, 0.095094897, 6.186466214]
avg_5 = [0.04417074, 1.27478025, 568.8695551]
avg_5err = [0.002327644, 0.074641636, 2.055645399]
avg_6 = [0.048690536, 1.639044561, 972.3250176]
avg_6err = [0.003389284, 0.060431562, 24.45023481]

# %%
plt.errorbar(n, avg_6, yerr=avg_6err, fmt='o-', capsize=2, label='6 contingencies', ms='12')
plt.errorbar(n, avg_5, yerr=avg_5err, fmt='o-', capsize=2, label='5 contingencies', ms='12')
plt.errorbar(n, avg_4, yerr=avg_4err, fmt='o-', capsize=2, label='4 contingencies', ms='12')
plt.errorbar(n, avg_3, yerr=avg_3err, fmt='o-', capsize=2, label='3 contingencies', ms='12')
plt.errorbar(n, avg_2, yerr=avg_2err, fmt='o-', capsize=2, label='2 contingencies', ms='12')
plt.errorbar(n, avg_1, yerr=avg_1err, fmt='o-', capsize=2, label='1 contingencies', ms='12')
plt.yscale('log')
plt.legend()
plt.ylabel('seconds')
plt.xlabel('size of network, N')
plt.title('time for execution of serial code at different network sizes and different number of contingencies')
plt.show();
